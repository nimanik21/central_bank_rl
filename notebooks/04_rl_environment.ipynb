# %%
import sys
import os

# Ensure Python finds config.py
sys.path.append(os.path.abspath(".."))  # Moves up one level to find config.py

# %%
import os
import gym
import numpy as np
import pandas as pd
import pickle
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback

# --- Import local config ---
from config import MODELS_DIR, PROCESSED_DATA_DIR, LOGS_DIR

# Define the CentralBankEnv environment
class CentralBankEnv(gym.Env):
    def __init__(self, varmax_model_path, train_data_path, optimal_lag, episode_length=60):
        super().__init__()

        with open(varmax_model_path, "rb") as f:
            self.varmax_model = pickle.load(f)

        self.train_data = pd.read_csv(train_data_path, index_col="date", parse_dates=True)

        self.exogenous_vars = ["FEDFUNDS"]
        self.endogenous_vars = [col for col in self.train_data.columns if col not in self.exogenous_vars]

        if len(self.endogenous_vars) < 1:
            raise ValueError("Dataset must contain at least one endogenous variable!")

        self.optimal_lag = optimal_lag
        self.episode_length = episode_length

        num_features = len(self.endogenous_vars) + len(self.exogenous_vars)
        self.expected_shape = (self.optimal_lag, num_features)

        self.action_mapping = np.array([-0.50, -0.25, 0, 0.25, 0.50])
        self.action_space = spaces.Discrete(len(self.action_mapping))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.expected_shape, dtype=np.float32)

        self.ffr_min, self.ffr_max = self.train_data["FEDFUNDS"].min(), self.train_data["FEDFUNDS"].max()

        if "CPIAUCSL" in self.endogenous_vars:
            self.inflation_idx = self.endogenous_vars.index("CPIAUCSL")
        else:
            raise KeyError("CPICPIAUCSLnot found in dataset!")

        self.steps = 0

        # Reward logging
        self.episode_rewards = []  # List to store total rewards per episode
        self.current_episode_rewards = 0

    def reset(self):
        """Resets the environment and logs the previous episode rewards."""
        # Log previous episode if not the very first call to reset
        if self.steps > 0:
            self.episode_rewards.append(self.current_episode_rewards)
            # Note: The callback below will also print these, so you can remove this print if you prefer.
            print(f"Episode {len(self.episode_rewards)} completed. Total Reward: {self.current_episode_rewards:.3f}")

        self.steps = 0
        self.current_episode_rewards = 0

        max_start_idx = len(self.train_data) - self.optimal_lag - 1
        if max_start_idx <= 0:
            raise ValueError(
                f"Not enough train data! Dataset size: {len(self.train_data)}, required minimum: {self.optimal_lag + 1}"
            )

        start_idx = np.random.randint(0, max_start_idx)
        self.history = self.train_data.iloc[start_idx : start_idx + self.optimal_lag][
            self.endogenous_vars + self.exogenous_vars
        ].to_numpy(copy=False)
        self.last_ffr = self.history[-1, -1]

        return self.history

    def step(self, action):
        """Executes an action, updates the state, logs rewards, and returns the new state."""
        ffr_change = self.action_mapping[action]
        new_ffr = np.clip(self.last_ffr + ffr_change, self.ffr_min, self.ffr_max)

        # Forecast one step using the new FFR as the exogenous input
        next_state_df = self.varmax_model.forecast(steps=1, exog=np.array([[new_ffr]]))
        next_state = next_state_df[self.endogenous_vars].iloc[0].values.reshape(1, -1)

        new_row = np.hstack([next_state, np.array([[new_ffr]])])
        self.history = np.vstack([self.history[1:], new_row])
        self.last_ffr = new_ffr

        if self.history.shape != self.expected_shape:
            raise ValueError(
                f"History shape mismatch: Expected {self.expected_shape}, got {self.history.shape}"
            )

        reward = self._reward(next_state.flatten(), action)
        self.current_episode_rewards += reward

        self.steps += 1
        done = self.steps >= self.episode_length

        return self.history, reward, done, {}

    def _reward(self, next_state, action):
        """Computes reward based on macroeconomic stability and policy smoothness."""
        inflation = next_state[self.inflation_idx]
        pi_target = 0.02
        alpha, lamb = 0.5, 0.1
        return - (alpha * (inflation - pi_target) ** 2 + lamb * (action ** 2))

    def get_episode_rewards(self):
        """Returns the list of total rewards for completed episodes."""
        return self.episode_rewards

# Define a custom callback to print episode rewards as training progresses
class EpisodeRewardLoggingCallback(BaseCallback):
    def __init__(self, verbose=1):
        super(EpisodeRewardLoggingCallback, self).__init__(verbose)
        self.last_logged = 0

    def _on_step(self) -> bool:
        # Retrieve episode rewards from the training environment (list per env)
        episode_rewards = self.training_env.get_attr("episode_rewards")
        if episode_rewards and episode_rewards[0]:
            rewards = episode_rewards[0]
            # If there are new episodes completed, print their rewards
            while self.last_logged < len(rewards):
                print(f"Episode {self.last_logged + 1} completed with total reward: {rewards[self.last_logged]:.3f}")
                self.last_logged += 1
        return True

# %%
# Build file paths using config values
varmax_model_path = os.path.join(MODELS_DIR, "varmax_model.pkl")
rl_train_data_path = os.path.join(PROCESSED_DATA_DIR, "rl_train_data.csv")
model_path = os.path.join(MODELS_DIR, "ppo_central_bank")
reward_log_path = os.path.join(LOGS_DIR, "rl_rewards.csv")

def make_env():
    return CentralBankEnv(
        varmax_model_path=varmax_model_path,
        train_data_path=rl_train_data_path,
        optimal_lag=4,
        episode_length=60
    )

# Wrap the environment in DummyVecEnv 
env = DummyVecEnv([make_env])

# Create the callback instance for logging episode rewards
episode_reward_callback = EpisodeRewardLoggingCallback(verbose=1)

# Define the RL model (PPO) and start training with the callback
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=os.path.join(LOGS_DIR, "ppo_central_bank"))
model.learn(total_timesteps=100_000, callback=episode_reward_callback)

# Save the trained model
os.makedirs(os.path.dirname(model_path), exist_ok=True)
model.save(model_path)
print(f"RL Model saved at: {model_path}")

# Save the logged episode rewards to a CSV file
env_rewards = env.get_attr("episode_rewards")[0]  # get_attr returns a list per env
pd.DataFrame(env_rewards, columns=["Total Reward"]).to_csv(reward_log_path, index=False)
print(f"Episode rewards logged at: {reward_log_path}")
# Out:
# Using cpu device
# Logging to /Users/nim/Documents/Research/central_bank_rl/logs/ppo_central_bank/PPO_4
# /Applications/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Episode 1 completed. Total Reward: -49.055
# Episode 1 completed with total reward: -49.055
# Episode 2 completed. Total Reward: -56.608
# Episode 2 completed with total reward: -56.608
# Episode 3 completed. Total Reward: -51.237
# Episode 3 completed with total reward: -51.237
# Episode 4 completed. Total Reward: -44.141
# Episode 4 completed with total reward: -44.141
# Episode 5 completed. Total Reward: -53.230
# Episode 5 completed with total reward: -53.230
# Episode 6 completed. Total Reward: -56.099
# Episode 6 completed with total reward: -56.099
# Episode 7 completed. Total Reward: -55.834
# Episode 7 completed with total reward: -55.834
# Episode 8 completed. Total Reward: -49.855
# Episode 8 completed with total reward: -49.855
# Episode 9 completed. Total Reward: -55.698
# Episode 9 completed with total reward: -55.698
# Episode 10 completed. Total Reward: -54.038
# Episode 10 completed with total reward: -54.038
# Episode 11 completed. Total Reward: -48.540
# Episode 11 completed with total reward: -48.540
# Episode 12 completed. Total Reward: -55.709
# Episode 12 completed with total reward: -55.709
# Episode 13 completed. Total Reward: -54.241
# Episode 13 completed with total reward: -54.241
# Episode 14 completed. Total Reward: -54.294
# Episode 14 completed with total reward: -54.294
# Episode 15 completed. Total Reward: -57.387
# Episode 15 completed with total reward: -57.387
# Episode 16 completed. Total Reward: -53.552
# Episode 16 completed with total reward: -53.552
# Episode 17 completed. Total Reward: -52.049
# Episode 17 completed with total reward: -52.049
# Episode 18 completed. Total Reward: -49.639
# Episode 18 completed with total reward: -49.639
# Episode 19 completed. Total Reward: -45.877
# Episode 19 completed with total reward: -45.877
# Episode 20 completed. Total Reward: -51.445
# Episode 20 completed with total reward: -51.445
# Episode 21 completed. Total Reward: -52.276
# Episode 21 completed with total reward: -52.276
# Episode 22 completed. Total Reward: -48.890
# Episode 22 completed with total reward: -48.890
# Episode 23 completed. Total Reward: -56.754
# Episode 23 completed with total reward: -56.754
# Episode 24 completed. Total Reward: -55.416
# Episode 24 completed with total reward: -55.416
# Episode 25 completed. Total Reward: -56.066
# Episode 25 completed with total reward: -56.066
# Episode 26 completed. Total Reward: -57.580
# Episode 26 completed with total reward: -57.580
# Episode 27 completed. Total Reward: -46.981
# Episode 27 completed with total reward: -46.981
# Episode 28 completed. Total Reward: -58.587
# Episode 28 completed with total reward: -58.587
# Episode 29 completed. Total Reward: -54.276
# Episode 29 completed with total reward: -54.276
# Episode 30 completed. Total Reward: -48.276
# Episode 30 completed with total reward: -48.276
# Episode 31 completed. Total Reward: -56.824
# Episode 31 completed with total reward: -56.824
# Episode 32 completed. Total Reward: -50.788
# Episode 32 completed with total reward: -50.788
# Episode 33 completed. Total Reward: -52.023
# Episode 33 completed with total reward: -52.023
# Episode 34 completed. Total Reward: -49.541
# Episode 34 completed with total reward: -49.541
# -----------------------------
# | time/              |      |
# |    fps             | 62   |
# |    iterations      | 1    |
# |    time_elapsed    | 32   |
# |    total_timesteps | 2048 |
# -----------------------------
# Episode 35 completed. Total Reward: -49.296
# Episode 35 completed with total reward: -49.296
# Episode 36 completed. Total Reward: -47.701
# Episode 36 completed with total reward: -47.701
# Episode 37 completed. Total Reward: -51.088
# Episode 37 completed with total reward: -51.088
# Episode 38 completed. Total Reward: -50.457
# Episode 38 completed with total reward: -50.457
# Episode 39 completed. Total Reward: -49.899
# Episode 39 completed with total reward: -49.899
# Episode 40 completed. Total Reward: -51.752
# Episode 40 completed with total reward: -51.752
# Episode 41 completed. Total Reward: -51.717
# Episode 41 completed with total reward: -51.717
# Episode 42 completed. Total Reward: -57.229
# Episode 42 completed with total reward: -57.229
# Episode 43 completed. Total Reward: -49.102
# Episode 43 completed with total reward: -49.102
# Episode 44 completed. Total Reward: -57.639
# Episode 44 completed with total reward: -57.639
# Episode 45 completed. Total Reward: -50.612
# Episode 45 completed with total reward: -50.612
# Episode 46 completed. Total Reward: -50.930
# Episode 46 completed with total reward: -50.930
# Episode 47 completed. Total Reward: -52.219
# Episode 47 completed with total reward: -52.219
# Episode 48 completed. Total Reward: -48.268
# Episode 48 completed with total reward: -48.268
# Episode 49 completed. Total Reward: -44.620
# Episode 49 completed with total reward: -44.620
# Episode 50 completed. Total Reward: -45.657
# Episode 50 completed with total reward: -45.657
# Episode 51 completed. Total Reward: -54.226
# Episode 51 completed with total reward: -54.226
# Episode 52 completed. Total Reward: -49.888
# Episode 52 completed with total reward: -49.888
# Episode 53 completed. Total Reward: -48.525
# Episode 53 completed with total reward: -48.525
# Episode 54 completed. Total Reward: -52.199
# Episode 54 completed with total reward: -52.199
# Episode 55 completed. Total Reward: -46.803
# Episode 55 completed with total reward: -46.803
# Episode 56 completed. Total Reward: -47.147
# Episode 56 completed with total reward: -47.147
# Episode 57 completed. Total Reward: -51.870
# Episode 57 completed with total reward: -51.870
# Episode 58 completed. Total Reward: -52.956
# Episode 58 completed with total reward: -52.956
# Episode 59 completed. Total Reward: -48.644
# Episode 59 completed with total reward: -48.644
# Episode 60 completed. Total Reward: -51.883
# Episode 60 completed with total reward: -51.883
# Episode 61 completed. Total Reward: -51.232
# Episode 61 completed with total reward: -51.232
# Episode 62 completed. Total Reward: -56.923
# Episode 62 completed with total reward: -56.923
# Episode 63 completed. Total Reward: -51.965
# Episode 63 completed with total reward: -51.965
# Episode 64 completed. Total Reward: -54.698
# Episode 64 completed with total reward: -54.698
# Episode 65 completed. Total Reward: -49.983
# Episode 65 completed with total reward: -49.983
# Episode 66 completed. Total Reward: -54.366
# Episode 66 completed with total reward: -54.366
# Episode 67 completed. Total Reward: -53.154
# Episode 67 completed with total reward: -53.154
# Episode 68 completed. Total Reward: -49.041
# Episode 68 completed with total reward: -49.041
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 2           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010512136 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.00717     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 39.3        |
# -----------------------------------------
# Episode 69 completed. Total Reward: -44.717
# Episode 69 completed with total reward: -44.717
# Episode 70 completed. Total Reward: -47.457
# Episode 70 completed with total reward: -47.457
# Episode 71 completed. Total Reward: -45.319
# Episode 71 completed with total reward: -45.319
# Episode 72 completed. Total Reward: -50.156
# Episode 72 completed with total reward: -50.156
# Episode 73 completed. Total Reward: -53.184
# Episode 73 completed with total reward: -53.184
# Episode 74 completed. Total Reward: -49.981
# Episode 74 completed with total reward: -49.981
# Episode 75 completed. Total Reward: -51.001
# Episode 75 completed with total reward: -51.001
# Episode 76 completed. Total Reward: -44.286
# Episode 76 completed with total reward: -44.286
# Episode 77 completed. Total Reward: -58.892
# Episode 77 completed with total reward: -58.892
# Episode 78 completed. Total Reward: -52.614
# Episode 78 completed with total reward: -52.614
# Episode 79 completed. Total Reward: -51.923
# Episode 79 completed with total reward: -51.923
# Episode 80 completed. Total Reward: -49.924
# Episode 80 completed with total reward: -49.924
# Episode 81 completed. Total Reward: -49.889
# Episode 81 completed with total reward: -49.889
# Episode 82 completed. Total Reward: -51.669
# Episode 82 completed with total reward: -51.669
# Episode 83 completed. Total Reward: -49.838
# Episode 83 completed with total reward: -49.838
# Episode 84 completed. Total Reward: -52.420
# Episode 84 completed with total reward: -52.420
# Episode 85 completed. Total Reward: -41.467
# Episode 85 completed with total reward: -41.467
# Episode 86 completed. Total Reward: -43.011
# Episode 86 completed with total reward: -43.011
# Episode 87 completed. Total Reward: -49.097
# Episode 87 completed with total reward: -49.097
# Episode 88 completed. Total Reward: -44.426
# Episode 88 completed with total reward: -44.426
# Episode 89 completed. Total Reward: -50.184
# Episode 89 completed with total reward: -50.184
# Episode 90 completed. Total Reward: -46.002
# Episode 90 completed with total reward: -46.002
# Episode 91 completed. Total Reward: -47.025
# Episode 91 completed with total reward: -47.025
# Episode 92 completed. Total Reward: -51.735
# Episode 92 completed with total reward: -51.735
# Episode 93 completed. Total Reward: -52.292
# Episode 93 completed with total reward: -52.292
# Episode 94 completed. Total Reward: -46.865
# Episode 94 completed with total reward: -46.865
# Episode 95 completed. Total Reward: -53.243
# Episode 95 completed with total reward: -53.243
# Episode 96 completed. Total Reward: -47.754
# Episode 96 completed with total reward: -47.754
# Episode 97 completed. Total Reward: -39.719
# Episode 97 completed with total reward: -39.719
# Episode 98 completed. Total Reward: -49.582
# Episode 98 completed with total reward: -49.582
# Episode 99 completed. Total Reward: -48.769
# Episode 99 completed with total reward: -48.769
# Episode 100 completed. Total Reward: -56.125
# Episode 100 completed with total reward: -56.125
# Episode 101 completed. Total Reward: -46.917
# Episode 101 completed with total reward: -46.917
# Episode 102 completed. Total Reward: -49.754
# Episode 102 completed with total reward: -49.754
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 3            |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0054428997 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | -0.0591      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 53.4         |
# ------------------------------------------
# Episode 103 completed. Total Reward: -46.359
# Episode 103 completed with total reward: -46.359
# Episode 104 completed. Total Reward: -47.581
# Episode 104 completed with total reward: -47.581
# Episode 105 completed. Total Reward: -48.357
# Episode 105 completed with total reward: -48.357
# Episode 106 completed. Total Reward: -50.805
# Episode 106 completed with total reward: -50.805
# Episode 107 completed. Total Reward: -49.516
# Episode 107 completed with total reward: -49.516
# Episode 108 completed. Total Reward: -53.633
# Episode 108 completed with total reward: -53.633
# Episode 109 completed. Total Reward: -51.789
# Episode 109 completed with total reward: -51.789
# Episode 110 completed. Total Reward: -52.427
# Episode 110 completed with total reward: -52.427
# Episode 111 completed. Total Reward: -46.750
# Episode 111 completed with total reward: -46.750
# Episode 112 completed. Total Reward: -49.422
# Episode 112 completed with total reward: -49.422
# Episode 113 completed. Total Reward: -48.239
# Episode 113 completed with total reward: -48.239
# Episode 114 completed. Total Reward: -46.154
# Episode 114 completed with total reward: -46.154
# Episode 115 completed. Total Reward: -51.613
# Episode 115 completed with total reward: -51.613
# Episode 116 completed. Total Reward: -45.366
# Episode 116 completed with total reward: -45.366
# Episode 117 completed. Total Reward: -49.091
# Episode 117 completed with total reward: -49.091
# Episode 118 completed. Total Reward: -51.827
# Episode 118 completed with total reward: -51.827
# Episode 119 completed. Total Reward: -38.585
# Episode 119 completed with total reward: -38.585
# Episode 120 completed. Total Reward: -49.568
# Episode 120 completed with total reward: -49.568
# Episode 121 completed. Total Reward: -48.496
# Episode 121 completed with total reward: -48.496
# Episode 122 completed. Total Reward: -43.095
# Episode 122 completed with total reward: -43.095
# Episode 123 completed. Total Reward: -44.440
# Episode 123 completed with total reward: -44.440
# Episode 124 completed. Total Reward: -51.080
# Episode 124 completed with total reward: -51.080
# Episode 125 completed. Total Reward: -51.041
# Episode 125 completed with total reward: -51.041
# Episode 126 completed. Total Reward: -48.483
# Episode 126 completed with total reward: -48.483
# Episode 127 completed. Total Reward: -49.231
# Episode 127 completed with total reward: -49.231
# Episode 128 completed. Total Reward: -47.537
# Episode 128 completed with total reward: -47.537
# Episode 129 completed. Total Reward: -43.572
# Episode 129 completed with total reward: -43.572
# Episode 130 completed. Total Reward: -47.733
# Episode 130 completed with total reward: -47.733
# Episode 131 completed. Total Reward: -48.951
# Episode 131 completed with total reward: -48.951
# Episode 132 completed. Total Reward: -51.846
# Episode 132 completed with total reward: -51.846
# Episode 133 completed. Total Reward: -48.716
# Episode 133 completed with total reward: -48.716
# Episode 134 completed. Total Reward: -47.119
# Episode 134 completed with total reward: -47.119
# Episode 135 completed. Total Reward: -46.743
# Episode 135 completed with total reward: -46.743
# Episode 136 completed. Total Reward: -49.253
# Episode 136 completed with total reward: -49.253
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 4           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006639978 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | -0.063      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 57.5        |
# -----------------------------------------
# Episode 137 completed. Total Reward: -44.165
# Episode 137 completed with total reward: -44.165
# Episode 138 completed. Total Reward: -54.166
# Episode 138 completed with total reward: -54.166
# Episode 139 completed. Total Reward: -47.790
# Episode 139 completed with total reward: -47.790
# Episode 140 completed. Total Reward: -42.465
# Episode 140 completed with total reward: -42.465
# Episode 141 completed. Total Reward: -46.924
# Episode 141 completed with total reward: -46.924
# Episode 142 completed. Total Reward: -44.907
# Episode 142 completed with total reward: -44.907
# Episode 143 completed. Total Reward: -47.795
# Episode 143 completed with total reward: -47.795
# Episode 144 completed. Total Reward: -50.456
# Episode 144 completed with total reward: -50.456
# Episode 145 completed. Total Reward: -47.701
# Episode 145 completed with total reward: -47.701
# Episode 146 completed. Total Reward: -49.382
# Episode 146 completed with total reward: -49.382
# Episode 147 completed. Total Reward: -51.069
# Episode 147 completed with total reward: -51.069
# Episode 148 completed. Total Reward: -43.280
# Episode 148 completed with total reward: -43.280
# Episode 149 completed. Total Reward: -51.384
# Episode 149 completed with total reward: -51.384
# Episode 150 completed. Total Reward: -43.959
# Episode 150 completed with total reward: -43.959
# Episode 151 completed. Total Reward: -44.801
# Episode 151 completed with total reward: -44.801
# Episode 152 completed. Total Reward: -52.149
# Episode 152 completed with total reward: -52.149
# Episode 153 completed. Total Reward: -39.977
# Episode 153 completed with total reward: -39.977
# Episode 154 completed. Total Reward: -48.387
# Episode 154 completed with total reward: -48.387
# Episode 155 completed. Total Reward: -49.725
# Episode 155 completed with total reward: -49.725
# Episode 156 completed. Total Reward: -40.918
# Episode 156 completed with total reward: -40.918
# Episode 157 completed. Total Reward: -43.857
# Episode 157 completed with total reward: -43.857
# Episode 158 completed. Total Reward: -50.068
# Episode 158 completed with total reward: -50.068
# Episode 159 completed. Total Reward: -44.993
# Episode 159 completed with total reward: -44.993
# Episode 160 completed. Total Reward: -50.506
# Episode 160 completed with total reward: -50.506
# Episode 161 completed. Total Reward: -45.179
# Episode 161 completed with total reward: -45.179
# Episode 162 completed. Total Reward: -45.774
# Episode 162 completed with total reward: -45.774
# Episode 163 completed. Total Reward: -43.260
# Episode 163 completed with total reward: -43.260
# Episode 164 completed. Total Reward: -54.322
# Episode 164 completed with total reward: -54.322
# Episode 165 completed. Total Reward: -45.128
# Episode 165 completed with total reward: -45.128
# Episode 166 completed. Total Reward: -40.599
# Episode 166 completed with total reward: -40.599
# Episode 167 completed. Total Reward: -41.867
# Episode 167 completed with total reward: -41.867
# Episode 168 completed. Total Reward: -49.310
# Episode 168 completed with total reward: -49.310
# Episode 169 completed. Total Reward: -50.519
# Episode 169 completed with total reward: -50.519
# Episode 170 completed. Total Reward: -42.621
# Episode 170 completed with total reward: -42.621
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 5           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007775779 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | -0.0465     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 67.5        |
# -----------------------------------------
# Episode 171 completed. Total Reward: -44.851
# Episode 171 completed with total reward: -44.851
# Episode 172 completed. Total Reward: -43.296
# Episode 172 completed with total reward: -43.296
# Episode 173 completed. Total Reward: -44.507
# Episode 173 completed with total reward: -44.507
# Episode 174 completed. Total Reward: -49.571
# Episode 174 completed with total reward: -49.571
# Episode 175 completed. Total Reward: -44.016
# Episode 175 completed with total reward: -44.016
# Episode 176 completed. Total Reward: -43.570
# Episode 176 completed with total reward: -43.570
# Episode 177 completed. Total Reward: -44.895
# Episode 177 completed with total reward: -44.895
# Episode 178 completed. Total Reward: -51.040
# Episode 178 completed with total reward: -51.040
# Episode 179 completed. Total Reward: -48.551
# Episode 179 completed with total reward: -48.551
# Episode 180 completed. Total Reward: -49.085
# Episode 180 completed with total reward: -49.085
# Episode 181 completed. Total Reward: -48.341
# Episode 181 completed with total reward: -48.341
# Episode 182 completed. Total Reward: -41.762
# Episode 182 completed with total reward: -41.762
# Episode 183 completed. Total Reward: -51.679
# Episode 183 completed with total reward: -51.679
# Episode 184 completed. Total Reward: -47.647
# Episode 184 completed with total reward: -47.647
# Episode 185 completed. Total Reward: -49.628
# Episode 185 completed with total reward: -49.628
# Episode 186 completed. Total Reward: -44.847
# Episode 186 completed with total reward: -44.847
# Episode 187 completed. Total Reward: -49.453
# Episode 187 completed with total reward: -49.453
# Episode 188 completed. Total Reward: -39.021
# Episode 188 completed with total reward: -39.021
# Episode 189 completed. Total Reward: -52.209
# Episode 189 completed with total reward: -52.209
# Episode 190 completed. Total Reward: -50.413
# Episode 190 completed with total reward: -50.413
# Episode 191 completed. Total Reward: -49.660
# Episode 191 completed with total reward: -49.660
# Episode 192 completed. Total Reward: -48.298
# Episode 192 completed with total reward: -48.298
# Episode 193 completed. Total Reward: -46.505
# Episode 193 completed with total reward: -46.505
# Episode 194 completed. Total Reward: -50.743
# Episode 194 completed with total reward: -50.743
# Episode 195 completed. Total Reward: -41.956
# Episode 195 completed with total reward: -41.956
# Episode 196 completed. Total Reward: -39.053
# Episode 196 completed with total reward: -39.053
# Episode 197 completed. Total Reward: -46.726
# Episode 197 completed with total reward: -46.726
# Episode 198 completed. Total Reward: -45.979
# Episode 198 completed with total reward: -45.979
# Episode 199 completed. Total Reward: -47.091
# Episode 199 completed with total reward: -47.091
# Episode 200 completed. Total Reward: -44.995
# Episode 200 completed with total reward: -44.995
# Episode 201 completed. Total Reward: -43.082
# Episode 201 completed with total reward: -43.082
# Episode 202 completed. Total Reward: -44.181
# Episode 202 completed with total reward: -44.181
# Episode 203 completed. Total Reward: -44.738
# Episode 203 completed with total reward: -44.738
# Episode 204 completed. Total Reward: -45.531
# Episode 204 completed with total reward: -45.531
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 6            |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0095469905 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.0108      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00934     |
# |    value_loss           | 68.4         |
# ------------------------------------------
# Episode 205 completed. Total Reward: -50.667
# Episode 205 completed with total reward: -50.667
# Episode 206 completed. Total Reward: -38.615
# Episode 206 completed with total reward: -38.615
# Episode 207 completed. Total Reward: -47.228
# Episode 207 completed with total reward: -47.228
# Episode 208 completed. Total Reward: -51.081
# Episode 208 completed with total reward: -51.081
# Episode 209 completed. Total Reward: -42.497
# Episode 209 completed with total reward: -42.497
# Episode 210 completed. Total Reward: -41.190
# Episode 210 completed with total reward: -41.190
# Episode 211 completed. Total Reward: -41.067
# Episode 211 completed with total reward: -41.067
# Episode 212 completed. Total Reward: -45.752
# Episode 212 completed with total reward: -45.752
# Episode 213 completed. Total Reward: -44.347
# Episode 213 completed with total reward: -44.347
# Episode 214 completed. Total Reward: -48.082
# Episode 214 completed with total reward: -48.082
# Episode 215 completed. Total Reward: -48.226
# Episode 215 completed with total reward: -48.226
# Episode 216 completed. Total Reward: -46.240
# Episode 216 completed with total reward: -46.240
# Episode 217 completed. Total Reward: -43.816
# Episode 217 completed with total reward: -43.816
# Episode 218 completed. Total Reward: -40.332
# Episode 218 completed with total reward: -40.332
# Episode 219 completed. Total Reward: -43.374
# Episode 219 completed with total reward: -43.374
# Episode 220 completed. Total Reward: -49.362
# Episode 220 completed with total reward: -49.362
# Episode 221 completed. Total Reward: -40.097
# Episode 221 completed with total reward: -40.097
# Episode 222 completed. Total Reward: -44.648
# Episode 222 completed with total reward: -44.648
# Episode 223 completed. Total Reward: -45.050
# Episode 223 completed with total reward: -45.050
# Episode 224 completed. Total Reward: -32.619
# Episode 224 completed with total reward: -32.619
# Episode 225 completed. Total Reward: -45.389
# Episode 225 completed with total reward: -45.389
# Episode 226 completed. Total Reward: -37.024
# Episode 226 completed with total reward: -37.024
# Episode 227 completed. Total Reward: -39.116
# Episode 227 completed with total reward: -39.116
# Episode 228 completed. Total Reward: -41.287
# Episode 228 completed with total reward: -41.287
# Episode 229 completed. Total Reward: -45.825
# Episode 229 completed with total reward: -45.825
# Episode 230 completed. Total Reward: -39.102
# Episode 230 completed with total reward: -39.102
# Episode 231 completed. Total Reward: -43.019
# Episode 231 completed with total reward: -43.019
# Episode 232 completed. Total Reward: -45.293
# Episode 232 completed with total reward: -45.293
# Episode 233 completed. Total Reward: -42.461
# Episode 233 completed with total reward: -42.461
# Episode 234 completed. Total Reward: -39.875
# Episode 234 completed with total reward: -39.875
# Episode 235 completed. Total Reward: -43.353
# Episode 235 completed with total reward: -43.353
# Episode 236 completed. Total Reward: -44.880
# Episode 236 completed with total reward: -44.880
# Episode 237 completed. Total Reward: -40.484
# Episode 237 completed with total reward: -40.484
# Episode 238 completed. Total Reward: -40.228
# Episode 238 completed with total reward: -40.228
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 7           |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007401797 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.00325     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 70.6        |
# -----------------------------------------
# Episode 239 completed. Total Reward: -45.683
# Episode 239 completed with total reward: -45.683
# Episode 240 completed. Total Reward: -38.315
# Episode 240 completed with total reward: -38.315
# Episode 241 completed. Total Reward: -40.494
# Episode 241 completed with total reward: -40.494
# Episode 242 completed. Total Reward: -40.389
# Episode 242 completed with total reward: -40.389
# Episode 243 completed. Total Reward: -45.621
# Episode 243 completed with total reward: -45.621
# Episode 244 completed. Total Reward: -42.344
# Episode 244 completed with total reward: -42.344
# Episode 245 completed. Total Reward: -37.707
# Episode 245 completed with total reward: -37.707
# Episode 246 completed. Total Reward: -39.613
# Episode 246 completed with total reward: -39.613
# Episode 247 completed. Total Reward: -43.256
# Episode 247 completed with total reward: -43.256
# Episode 248 completed. Total Reward: -37.503
# Episode 248 completed with total reward: -37.503
# Episode 249 completed. Total Reward: -42.297
# Episode 249 completed with total reward: -42.297
# Episode 250 completed. Total Reward: -42.707
# Episode 250 completed with total reward: -42.707
# Episode 251 completed. Total Reward: -36.517
# Episode 251 completed with total reward: -36.517
# Episode 252 completed. Total Reward: -39.467
# Episode 252 completed with total reward: -39.467
# Episode 253 completed. Total Reward: -35.248
# Episode 253 completed with total reward: -35.248
# Episode 254 completed. Total Reward: -42.057
# Episode 254 completed with total reward: -42.057
# Episode 255 completed. Total Reward: -41.521
# Episode 255 completed with total reward: -41.521
# Episode 256 completed. Total Reward: -36.788
# Episode 256 completed with total reward: -36.788
# Episode 257 completed. Total Reward: -43.609
# Episode 257 completed with total reward: -43.609
# Episode 258 completed. Total Reward: -37.160
# Episode 258 completed with total reward: -37.160
# Episode 259 completed. Total Reward: -42.021
# Episode 259 completed with total reward: -42.021
# Episode 260 completed. Total Reward: -39.766
# Episode 260 completed with total reward: -39.766
# Episode 261 completed. Total Reward: -44.918
# Episode 261 completed with total reward: -44.918
# Episode 262 completed. Total Reward: -40.156
# Episode 262 completed with total reward: -40.156
# Episode 263 completed. Total Reward: -43.908
# Episode 263 completed with total reward: -43.908
# Episode 264 completed. Total Reward: -35.927
# Episode 264 completed with total reward: -35.927
# Episode 265 completed. Total Reward: -38.991
# Episode 265 completed with total reward: -38.991
# Episode 266 completed. Total Reward: -42.964
# Episode 266 completed with total reward: -42.964
# Episode 267 completed. Total Reward: -39.258
# Episode 267 completed with total reward: -39.258
# Episode 268 completed. Total Reward: -36.329
# Episode 268 completed with total reward: -36.329
# Episode 269 completed. Total Reward: -40.772
# Episode 269 completed with total reward: -40.772
# Episode 270 completed. Total Reward: -47.838
# Episode 270 completed with total reward: -47.838
# Episode 271 completed. Total Reward: -40.879
# Episode 271 completed with total reward: -40.879
# Episode 272 completed. Total Reward: -37.895
# Episode 272 completed with total reward: -37.895
# Episode 273 completed. Total Reward: -44.818
# Episode 273 completed with total reward: -44.818
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 8           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007291685 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.0349     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 68.7        |
# -----------------------------------------
# Episode 274 completed. Total Reward: -47.896
# Episode 274 completed with total reward: -47.896
# Episode 275 completed. Total Reward: -41.455
# Episode 275 completed with total reward: -41.455
# Episode 276 completed. Total Reward: -46.476
# Episode 276 completed with total reward: -46.476
# Episode 277 completed. Total Reward: -40.217
# Episode 277 completed with total reward: -40.217
# Episode 278 completed. Total Reward: -44.105
# Episode 278 completed with total reward: -44.105
# Episode 279 completed. Total Reward: -49.351
# Episode 279 completed with total reward: -49.351
# Episode 280 completed. Total Reward: -43.744
# Episode 280 completed with total reward: -43.744
# Episode 281 completed. Total Reward: -41.234
# Episode 281 completed with total reward: -41.234
# Episode 282 completed. Total Reward: -40.778
# Episode 282 completed with total reward: -40.778
# Episode 283 completed. Total Reward: -40.604
# Episode 283 completed with total reward: -40.604
# Episode 284 completed. Total Reward: -42.619
# Episode 284 completed with total reward: -42.619
# Episode 285 completed. Total Reward: -40.834
# Episode 285 completed with total reward: -40.834
# Episode 286 completed. Total Reward: -44.659
# Episode 286 completed with total reward: -44.659
# Episode 287 completed. Total Reward: -43.388
# Episode 287 completed with total reward: -43.388
# Episode 288 completed. Total Reward: -42.400
# Episode 288 completed with total reward: -42.400
# Episode 289 completed. Total Reward: -34.299
# Episode 289 completed with total reward: -34.299
# Episode 290 completed. Total Reward: -38.025
# Episode 290 completed with total reward: -38.025
# Episode 291 completed. Total Reward: -40.558
# Episode 291 completed with total reward: -40.558
# Episode 292 completed. Total Reward: -42.321
# Episode 292 completed with total reward: -42.321
# Episode 293 completed. Total Reward: -49.894
# Episode 293 completed with total reward: -49.894
# Episode 294 completed. Total Reward: -38.577
# Episode 294 completed with total reward: -38.577
# Episode 295 completed. Total Reward: -46.661
# Episode 295 completed with total reward: -46.661
# Episode 296 completed. Total Reward: -35.473
# Episode 296 completed with total reward: -35.473
# Episode 297 completed. Total Reward: -48.882
# Episode 297 completed with total reward: -48.882
# Episode 298 completed. Total Reward: -42.238
# Episode 298 completed with total reward: -42.238
# Episode 299 completed. Total Reward: -40.653
# Episode 299 completed with total reward: -40.653
# Episode 300 completed. Total Reward: -37.982
# Episode 300 completed with total reward: -37.982
# Episode 301 completed. Total Reward: -41.447
# Episode 301 completed with total reward: -41.447
# Episode 302 completed. Total Reward: -39.581
# Episode 302 completed with total reward: -39.581
# Episode 303 completed. Total Reward: -45.035
# Episode 303 completed with total reward: -45.035
# Episode 304 completed. Total Reward: -44.527
# Episode 304 completed with total reward: -44.527
# Episode 305 completed. Total Reward: -43.470
# Episode 305 completed with total reward: -43.470
# Episode 306 completed. Total Reward: -52.205
# Episode 306 completed with total reward: -52.205
# Episode 307 completed. Total Reward: -50.740
# Episode 307 completed with total reward: -50.740
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 9           |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004613635 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.00703    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00596    |
# |    value_loss           | 63.3        |
# -----------------------------------------
# Episode 308 completed. Total Reward: -40.638
# Episode 308 completed with total reward: -40.638
# Episode 309 completed. Total Reward: -41.862
# Episode 309 completed with total reward: -41.862
# Episode 310 completed. Total Reward: -43.737
# Episode 310 completed with total reward: -43.737
# Episode 311 completed. Total Reward: -48.572
# Episode 311 completed with total reward: -48.572
# Episode 312 completed. Total Reward: -43.240
# Episode 312 completed with total reward: -43.240
# Episode 313 completed. Total Reward: -38.710
# Episode 313 completed with total reward: -38.710
# Episode 314 completed. Total Reward: -49.523
# Episode 314 completed with total reward: -49.523
# Episode 315 completed. Total Reward: -39.355
# Episode 315 completed with total reward: -39.355
# Episode 316 completed. Total Reward: -37.261
# Episode 316 completed with total reward: -37.261
# Episode 317 completed. Total Reward: -49.092
# Episode 317 completed with total reward: -49.092
# Episode 318 completed. Total Reward: -40.912
# Episode 318 completed with total reward: -40.912
# Episode 319 completed. Total Reward: -45.862
# Episode 319 completed with total reward: -45.862
# Episode 320 completed. Total Reward: -39.964
# Episode 320 completed with total reward: -39.964
# Episode 321 completed. Total Reward: -43.627
# Episode 321 completed with total reward: -43.627
# Episode 322 completed. Total Reward: -43.132
# Episode 322 completed with total reward: -43.132
# Episode 323 completed. Total Reward: -41.679
# Episode 323 completed with total reward: -41.679
# Episode 324 completed. Total Reward: -48.123
# Episode 324 completed with total reward: -48.123
# Episode 325 completed. Total Reward: -46.766
# Episode 325 completed with total reward: -46.766
# Episode 326 completed. Total Reward: -44.387
# Episode 326 completed with total reward: -44.387
# Episode 327 completed. Total Reward: -39.241
# Episode 327 completed with total reward: -39.241
# Episode 328 completed. Total Reward: -38.343
# Episode 328 completed with total reward: -38.343
# Episode 329 completed. Total Reward: -40.216
# Episode 329 completed with total reward: -40.216
# Episode 330 completed. Total Reward: -43.919
# Episode 330 completed with total reward: -43.919
# Episode 331 completed. Total Reward: -42.427
# Episode 331 completed with total reward: -42.427
# Episode 332 completed. Total Reward: -37.299
# Episode 332 completed with total reward: -37.299
# Episode 333 completed. Total Reward: -40.764
# Episode 333 completed with total reward: -40.764
# Episode 334 completed. Total Reward: -41.394
# Episode 334 completed with total reward: -41.394
# Episode 335 completed. Total Reward: -41.156
# Episode 335 completed with total reward: -41.156
# Episode 336 completed. Total Reward: -44.435
# Episode 336 completed with total reward: -44.435
# Episode 337 completed. Total Reward: -39.997
# Episode 337 completed with total reward: -39.997
# Episode 338 completed. Total Reward: -39.331
# Episode 338 completed with total reward: -39.331
# Episode 339 completed. Total Reward: -41.541
# Episode 339 completed with total reward: -41.541
# Episode 340 completed. Total Reward: -41.648
# Episode 340 completed with total reward: -41.648
# Episode 341 completed. Total Reward: -36.940
# Episode 341 completed with total reward: -36.940
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 10          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009485635 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 61.7        |
# -----------------------------------------
# Episode 342 completed. Total Reward: -42.089
# Episode 342 completed with total reward: -42.089
# Episode 343 completed. Total Reward: -39.824
# Episode 343 completed with total reward: -39.824
# Episode 344 completed. Total Reward: -40.430
# Episode 344 completed with total reward: -40.430
# Episode 345 completed. Total Reward: -42.043
# Episode 345 completed with total reward: -42.043
# Episode 346 completed. Total Reward: -41.827
# Episode 346 completed with total reward: -41.827
# Episode 347 completed. Total Reward: -42.193
# Episode 347 completed with total reward: -42.193
# Episode 348 completed. Total Reward: -35.811
# Episode 348 completed with total reward: -35.811
# Episode 349 completed. Total Reward: -38.950
# Episode 349 completed with total reward: -38.950
# Episode 350 completed. Total Reward: -39.570
# Episode 350 completed with total reward: -39.570
# Episode 351 completed. Total Reward: -40.905
# Episode 351 completed with total reward: -40.905
# Episode 352 completed. Total Reward: -41.475
# Episode 352 completed with total reward: -41.475
# Episode 353 completed. Total Reward: -44.219
# Episode 353 completed with total reward: -44.219
# Episode 354 completed. Total Reward: -42.833
# Episode 354 completed with total reward: -42.833
# Episode 355 completed. Total Reward: -39.802
# Episode 355 completed with total reward: -39.802
# Episode 356 completed. Total Reward: -34.655
# Episode 356 completed with total reward: -34.655
# Episode 357 completed. Total Reward: -38.896
# Episode 357 completed with total reward: -38.896
# Episode 358 completed. Total Reward: -38.517
# Episode 358 completed with total reward: -38.517
# Episode 359 completed. Total Reward: -41.555
# Episode 359 completed with total reward: -41.555
# Episode 360 completed. Total Reward: -42.832
# Episode 360 completed with total reward: -42.832
# Episode 361 completed. Total Reward: -41.056
# Episode 361 completed with total reward: -41.056
# Episode 362 completed. Total Reward: -39.133
# Episode 362 completed with total reward: -39.133
# Episode 363 completed. Total Reward: -42.014
# Episode 363 completed with total reward: -42.014
# Episode 364 completed. Total Reward: -38.413
# Episode 364 completed with total reward: -38.413
# Episode 365 completed. Total Reward: -46.433
# Episode 365 completed with total reward: -46.433
# Episode 366 completed. Total Reward: -40.126
# Episode 366 completed with total reward: -40.126
# Episode 367 completed. Total Reward: -37.782
# Episode 367 completed with total reward: -37.782
# Episode 368 completed. Total Reward: -38.141
# Episode 368 completed with total reward: -38.141
# Episode 369 completed. Total Reward: -38.630
# Episode 369 completed with total reward: -38.630
# Episode 370 completed. Total Reward: -38.719
# Episode 370 completed with total reward: -38.719
# Episode 371 completed. Total Reward: -41.331
# Episode 371 completed with total reward: -41.331
# Episode 372 completed. Total Reward: -39.140
# Episode 372 completed with total reward: -39.140
# Episode 373 completed. Total Reward: -37.969
# Episode 373 completed with total reward: -37.969
# Episode 374 completed. Total Reward: -45.775
# Episode 374 completed with total reward: -45.775
# Episode 375 completed. Total Reward: -41.745
# Episode 375 completed with total reward: -41.745
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 11           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0084187575 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0196       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.5         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0097      |
# |    value_loss           | 60.1         |
# ------------------------------------------
# Episode 376 completed. Total Reward: -41.202
# Episode 376 completed with total reward: -41.202
# Episode 377 completed. Total Reward: -39.919
# Episode 377 completed with total reward: -39.919
# Episode 378 completed. Total Reward: -38.064
# Episode 378 completed with total reward: -38.064
# Episode 379 completed. Total Reward: -36.392
# Episode 379 completed with total reward: -36.392
# Episode 380 completed. Total Reward: -35.747
# Episode 380 completed with total reward: -35.747
# Episode 381 completed. Total Reward: -38.025
# Episode 381 completed with total reward: -38.025
# Episode 382 completed. Total Reward: -32.610
# Episode 382 completed with total reward: -32.610
# Episode 383 completed. Total Reward: -39.010
# Episode 383 completed with total reward: -39.010
# Episode 384 completed. Total Reward: -34.459
# Episode 384 completed with total reward: -34.459
# Episode 385 completed. Total Reward: -35.253
# Episode 385 completed with total reward: -35.253
# Episode 386 completed. Total Reward: -44.318
# Episode 386 completed with total reward: -44.318
# Episode 387 completed. Total Reward: -38.355
# Episode 387 completed with total reward: -38.355
# Episode 388 completed. Total Reward: -35.777
# Episode 388 completed with total reward: -35.777
# Episode 389 completed. Total Reward: -37.303
# Episode 389 completed with total reward: -37.303
# Episode 390 completed. Total Reward: -42.975
# Episode 390 completed with total reward: -42.975
# Episode 391 completed. Total Reward: -39.885
# Episode 391 completed with total reward: -39.885
# Episode 392 completed. Total Reward: -31.432
# Episode 392 completed with total reward: -31.432
# Episode 393 completed. Total Reward: -39.738
# Episode 393 completed with total reward: -39.738
# Episode 394 completed. Total Reward: -38.707
# Episode 394 completed with total reward: -38.707
# Episode 395 completed. Total Reward: -38.809
# Episode 395 completed with total reward: -38.809
# Episode 396 completed. Total Reward: -45.134
# Episode 396 completed with total reward: -45.134
# Episode 397 completed. Total Reward: -37.642
# Episode 397 completed with total reward: -37.642
# Episode 398 completed. Total Reward: -40.567
# Episode 398 completed with total reward: -40.567
# Episode 399 completed. Total Reward: -34.449
# Episode 399 completed with total reward: -34.449
# Episode 400 completed. Total Reward: -35.058
# Episode 400 completed with total reward: -35.058
# Episode 401 completed. Total Reward: -43.669
# Episode 401 completed with total reward: -43.669
# Episode 402 completed. Total Reward: -39.176
# Episode 402 completed with total reward: -39.176
# Episode 403 completed. Total Reward: -44.009
# Episode 403 completed with total reward: -44.009
# Episode 404 completed. Total Reward: -33.267
# Episode 404 completed with total reward: -33.267
# Episode 405 completed. Total Reward: -39.156
# Episode 405 completed with total reward: -39.156
# Episode 406 completed. Total Reward: -42.870
# Episode 406 completed with total reward: -42.870
# Episode 407 completed. Total Reward: -34.868
# Episode 407 completed with total reward: -34.868
# Episode 408 completed. Total Reward: -37.006
# Episode 408 completed with total reward: -37.006
# Episode 409 completed. Total Reward: -35.998
# Episode 409 completed with total reward: -35.998
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 12          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010095218 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0217      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 57.2        |
# -----------------------------------------
# Episode 410 completed. Total Reward: -39.157
# Episode 410 completed with total reward: -39.157
# Episode 411 completed. Total Reward: -44.834
# Episode 411 completed with total reward: -44.834
# Episode 412 completed. Total Reward: -43.093
# Episode 412 completed with total reward: -43.093
# Episode 413 completed. Total Reward: -38.514
# Episode 413 completed with total reward: -38.514
# Episode 414 completed. Total Reward: -37.669
# Episode 414 completed with total reward: -37.669
# Episode 415 completed. Total Reward: -38.947
# Episode 415 completed with total reward: -38.947
# Episode 416 completed. Total Reward: -42.323
# Episode 416 completed with total reward: -42.323
# Episode 417 completed. Total Reward: -35.002
# ...
# Episode 1540 completed with total reward: -25.191
# Episode 1541 completed. Total Reward: -25.343
# Episode 1541 completed with total reward: -25.343
# Episode 1542 completed. Total Reward: -27.303
# Episode 1542 completed with total reward: -27.303
# Episode 1543 completed. Total Reward: -24.734
# Episode 1543 completed with total reward: -24.734
# Episode 1544 completed. Total Reward: -26.457
# Episode 1544 completed with total reward: -26.457
# Episode 1545 completed. Total Reward: -27.580
# Episode 1545 completed with total reward: -27.580
# Episode 1546 completed. Total Reward: -26.185
# Episode 1546 completed with total reward: -26.185
# Episode 1547 completed. Total Reward: -26.096
# Episode 1547 completed with total reward: -26.096
# Episode 1548 completed. Total Reward: -24.523
# Episode 1548 completed with total reward: -24.523
# Episode 1549 completed. Total Reward: -26.271
# Episode 1549 completed with total reward: -26.271
# Episode 1550 completed. Total Reward: -27.237
# Episode 1550 completed with total reward: -27.237
# Episode 1551 completed. Total Reward: -29.014
# Episode 1551 completed with total reward: -29.014
# Episode 1552 completed. Total Reward: -24.691
# Episode 1552 completed with total reward: -24.691
# Episode 1553 completed. Total Reward: -25.650
# Episode 1553 completed with total reward: -25.650
# Episode 1554 completed. Total Reward: -24.721
# Episode 1554 completed with total reward: -24.721
# Episode 1555 completed. Total Reward: -24.457
# Episode 1555 completed with total reward: -24.457
# Episode 1556 completed. Total Reward: -24.000
# Episode 1556 completed with total reward: -24.000
# Episode 1557 completed. Total Reward: -26.344
# Episode 1557 completed with total reward: -26.344
# Episode 1558 completed. Total Reward: -27.374
# Episode 1558 completed with total reward: -27.374
# Episode 1559 completed. Total Reward: -24.064
# Episode 1559 completed with total reward: -24.064
# Episode 1560 completed. Total Reward: -26.766
# Episode 1560 completed with total reward: -26.766
# Episode 1561 completed. Total Reward: -25.599
# Episode 1561 completed with total reward: -25.599
# Episode 1562 completed. Total Reward: -25.952
# Episode 1562 completed with total reward: -25.952
# Episode 1563 completed. Total Reward: -26.598
# Episode 1563 completed with total reward: -26.598
# Episode 1564 completed. Total Reward: -26.515
# Episode 1564 completed with total reward: -26.515
# Episode 1565 completed. Total Reward: -24.403
# Episode 1565 completed with total reward: -24.403
# Episode 1566 completed. Total Reward: -25.456
# Episode 1566 completed with total reward: -25.456
# Episode 1567 completed. Total Reward: -26.435
# Episode 1567 completed with total reward: -26.435
# Episode 1568 completed. Total Reward: -26.652
# Episode 1568 completed with total reward: -26.652
# Episode 1569 completed. Total Reward: -25.331
# Episode 1569 completed with total reward: -25.331
# Episode 1570 completed. Total Reward: -26.487
# Episode 1570 completed with total reward: -26.487
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 46           |
# |    time_elapsed         | 1541         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0031682537 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.208       |
# |    explained_variance   | 0.0945       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.4          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000127     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# Episode 1571 completed. Total Reward: -25.217
# Episode 1571 completed with total reward: -25.217
# Episode 1572 completed. Total Reward: -25.625
# Episode 1572 completed with total reward: -25.625
# Episode 1573 completed. Total Reward: -26.311
# Episode 1573 completed with total reward: -26.311
# Episode 1574 completed. Total Reward: -24.325
# Episode 1574 completed with total reward: -24.325
# Episode 1575 completed. Total Reward: -27.494
# Episode 1575 completed with total reward: -27.494
# Episode 1576 completed. Total Reward: -25.046
# Episode 1576 completed with total reward: -25.046
# Episode 1577 completed. Total Reward: -24.021
# Episode 1577 completed with total reward: -24.021
# Episode 1578 completed. Total Reward: -26.222
# Episode 1578 completed with total reward: -26.222
# Episode 1579 completed. Total Reward: -25.247
# Episode 1579 completed with total reward: -25.247
# Episode 1580 completed. Total Reward: -25.081
# Episode 1580 completed with total reward: -25.081
# Episode 1581 completed. Total Reward: -25.454
# Episode 1581 completed with total reward: -25.454
# Episode 1582 completed. Total Reward: -25.756
# Episode 1582 completed with total reward: -25.756
# Episode 1583 completed. Total Reward: -27.280
# Episode 1583 completed with total reward: -27.280
# Episode 1584 completed. Total Reward: -24.041
# Episode 1584 completed with total reward: -24.041
# Episode 1585 completed. Total Reward: -25.378
# Episode 1585 completed with total reward: -25.378
# Episode 1586 completed. Total Reward: -24.965
# Episode 1586 completed with total reward: -24.965
# Episode 1587 completed. Total Reward: -24.046
# Episode 1587 completed with total reward: -24.046
# Episode 1588 completed. Total Reward: -25.873
# Episode 1588 completed with total reward: -25.873
# Episode 1589 completed. Total Reward: -24.046
# Episode 1589 completed with total reward: -24.046
# Episode 1590 completed. Total Reward: -24.395
# Episode 1590 completed with total reward: -24.395
# Episode 1591 completed. Total Reward: -25.008
# Episode 1591 completed with total reward: -25.008
# Episode 1592 completed. Total Reward: -27.149
# Episode 1592 completed with total reward: -27.149
# Episode 1593 completed. Total Reward: -24.438
# Episode 1593 completed with total reward: -24.438
# Episode 1594 completed. Total Reward: -25.512
# Episode 1594 completed with total reward: -25.512
# Episode 1595 completed. Total Reward: -24.252
# Episode 1595 completed with total reward: -24.252
# Episode 1596 completed. Total Reward: -25.168
# Episode 1596 completed with total reward: -25.168
# Episode 1597 completed. Total Reward: -24.749
# Episode 1597 completed with total reward: -24.749
# Episode 1598 completed. Total Reward: -24.046
# Episode 1598 completed with total reward: -24.046
# Episode 1599 completed. Total Reward: -27.895
# Episode 1599 completed with total reward: -27.895
# Episode 1600 completed. Total Reward: -25.571
# Episode 1600 completed with total reward: -25.571
# Episode 1601 completed. Total Reward: -24.525
# Episode 1601 completed with total reward: -24.525
# Episode 1602 completed. Total Reward: -24.046
# Episode 1602 completed with total reward: -24.046
# Episode 1603 completed. Total Reward: -26.210
# Episode 1603 completed with total reward: -26.210
# Episode 1604 completed. Total Reward: -25.021
# Episode 1604 completed with total reward: -25.021
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 47          |
# |    time_elapsed         | 1574        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004555064 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | 0.0752      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000805   |
# |    value_loss           | 19          |
# -----------------------------------------
# Episode 1605 completed. Total Reward: -26.618
# Episode 1605 completed with total reward: -26.618
# Episode 1606 completed. Total Reward: -24.864
# Episode 1606 completed with total reward: -24.864
# Episode 1607 completed. Total Reward: -24.403
# Episode 1607 completed with total reward: -24.403
# Episode 1608 completed. Total Reward: -26.054
# Episode 1608 completed with total reward: -26.054
# Episode 1609 completed. Total Reward: -26.130
# Episode 1609 completed with total reward: -26.130
# Episode 1610 completed. Total Reward: -28.168
# Episode 1610 completed with total reward: -28.168
# Episode 1611 completed. Total Reward: -24.046
# Episode 1611 completed with total reward: -24.046
# Episode 1612 completed. Total Reward: -27.242
# Episode 1612 completed with total reward: -27.242
# Episode 1613 completed. Total Reward: -24.046
# Episode 1613 completed with total reward: -24.046
# Episode 1614 completed. Total Reward: -24.403
# Episode 1614 completed with total reward: -24.403
# Episode 1615 completed. Total Reward: -23.902
# Episode 1615 completed with total reward: -23.902
# Episode 1616 completed. Total Reward: -24.549
# Episode 1616 completed with total reward: -24.549
# Episode 1617 completed. Total Reward: -25.369
# Episode 1617 completed with total reward: -25.369
# Episode 1618 completed. Total Reward: -24.046
# Episode 1618 completed with total reward: -24.046
# Episode 1619 completed. Total Reward: -24.021
# Episode 1619 completed with total reward: -24.021
# Episode 1620 completed. Total Reward: -24.260
# Episode 1620 completed with total reward: -24.260
# Episode 1621 completed. Total Reward: -25.533
# Episode 1621 completed with total reward: -25.533
# Episode 1622 completed. Total Reward: -24.342
# Episode 1622 completed with total reward: -24.342
# Episode 1623 completed. Total Reward: -26.013
# Episode 1623 completed with total reward: -26.013
# Episode 1624 completed. Total Reward: -24.765
# Episode 1624 completed with total reward: -24.765
# Episode 1625 completed. Total Reward: -24.021
# Episode 1625 completed with total reward: -24.021
# Episode 1626 completed. Total Reward: -24.586
# Episode 1626 completed with total reward: -24.586
# Episode 1627 completed. Total Reward: -27.223
# Episode 1627 completed with total reward: -27.223
# Episode 1628 completed. Total Reward: -28.923
# Episode 1628 completed with total reward: -28.923
# Episode 1629 completed. Total Reward: -33.985
# Episode 1629 completed with total reward: -33.985
# Episode 1630 completed. Total Reward: -24.021
# Episode 1630 completed with total reward: -24.021
# Episode 1631 completed. Total Reward: -28.764
# Episode 1631 completed with total reward: -28.764
# Episode 1632 completed. Total Reward: -25.012
# Episode 1632 completed with total reward: -25.012
# Episode 1633 completed. Total Reward: -26.847
# Episode 1633 completed with total reward: -26.847
# Episode 1634 completed. Total Reward: -27.272
# Episode 1634 completed with total reward: -27.272
# Episode 1635 completed. Total Reward: -27.056
# Episode 1635 completed with total reward: -27.056
# Episode 1636 completed. Total Reward: -24.046
# Episode 1636 completed with total reward: -24.046
# Episode 1637 completed. Total Reward: -24.000
# Episode 1637 completed with total reward: -24.000
# Episode 1638 completed. Total Reward: -24.308
# Episode 1638 completed with total reward: -24.308
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 48           |
# |    time_elapsed         | 1607         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0050588557 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.0976       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.69         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000641     |
# |    value_loss           | 18.5         |
# ------------------------------------------
# Episode 1639 completed. Total Reward: -25.242
# Episode 1639 completed with total reward: -25.242
# Episode 1640 completed. Total Reward: -28.794
# Episode 1640 completed with total reward: -28.794
# Episode 1641 completed. Total Reward: -24.355
# Episode 1641 completed with total reward: -24.355
# Episode 1642 completed. Total Reward: -24.021
# Episode 1642 completed with total reward: -24.021
# Episode 1643 completed. Total Reward: -24.264
# Episode 1643 completed with total reward: -24.264
# Episode 1644 completed. Total Reward: -25.634
# Episode 1644 completed with total reward: -25.634
# Episode 1645 completed. Total Reward: -24.046
# Episode 1645 completed with total reward: -24.046
# Episode 1646 completed. Total Reward: -24.005
# Episode 1646 completed with total reward: -24.005
# Episode 1647 completed. Total Reward: -24.937
# Episode 1647 completed with total reward: -24.937
# Episode 1648 completed. Total Reward: -24.021
# Episode 1648 completed with total reward: -24.021
# Episode 1649 completed. Total Reward: -25.106
# Episode 1649 completed with total reward: -25.106
# Episode 1650 completed. Total Reward: -25.680
# Episode 1650 completed with total reward: -25.680
# Episode 1651 completed. Total Reward: -29.543
# Episode 1651 completed with total reward: -29.543
# Episode 1652 completed. Total Reward: -28.125
# Episode 1652 completed with total reward: -28.125
# Episode 1653 completed. Total Reward: -24.965
# Episode 1653 completed with total reward: -24.965
# Episode 1654 completed. Total Reward: -33.048
# Episode 1654 completed with total reward: -33.048
# Episode 1655 completed. Total Reward: -25.606
# Episode 1655 completed with total reward: -25.606
# Episode 1656 completed. Total Reward: -24.588
# Episode 1656 completed with total reward: -24.588
# Episode 1657 completed. Total Reward: -24.021
# Episode 1657 completed with total reward: -24.021
# Episode 1658 completed. Total Reward: -24.046
# Episode 1658 completed with total reward: -24.046
# Episode 1659 completed. Total Reward: -25.171
# Episode 1659 completed with total reward: -25.171
# Episode 1660 completed. Total Reward: -24.301
# Episode 1660 completed with total reward: -24.301
# Episode 1661 completed. Total Reward: -24.046
# Episode 1661 completed with total reward: -24.046
# Episode 1662 completed. Total Reward: -25.932
# Episode 1662 completed with total reward: -25.932
# Episode 1663 completed. Total Reward: -26.941
# Episode 1663 completed with total reward: -26.941
# Episode 1664 completed. Total Reward: -27.793
# Episode 1664 completed with total reward: -27.793
# Episode 1665 completed. Total Reward: -25.412
# Episode 1665 completed with total reward: -25.412
# Episode 1666 completed. Total Reward: -24.027
# Episode 1666 completed with total reward: -24.027
# Episode 1667 completed. Total Reward: -24.000
# Episode 1667 completed with total reward: -24.000
# Episode 1668 completed. Total Reward: -24.446
# Episode 1668 completed with total reward: -24.446
# Episode 1669 completed. Total Reward: -24.403
# Episode 1669 completed with total reward: -24.403
# Episode 1670 completed. Total Reward: -24.021
# Episode 1670 completed with total reward: -24.021
# Episode 1671 completed. Total Reward: -27.477
# Episode 1671 completed with total reward: -27.477
# Episode 1672 completed. Total Reward: -26.824
# Episode 1672 completed with total reward: -26.824
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 49           |
# |    time_elapsed         | 1642         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013758852 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.134       |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.4          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000324    |
# |    value_loss           | 18.1         |
# ------------------------------------------
# RL Model saved at: /Users/nim/Documents/Research/central_bank_rl/models/ppo_central_bank
# Episode rewards logged at: /Users/nim/Documents/Research/central_bank_rl/logs/rl_rewards.csv
